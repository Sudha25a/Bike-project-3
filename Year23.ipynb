# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
Year23 = pd.read_csv('data_2023.csv')

# %%
Year23.head()
# Out:
#             ride_id  rideable_type        started_at          ended_at  \
# 0  4B88BE3AEA4FD3C2   classic_bike  01-01-2023 00:03  01-01-2023 00:41
# 1  B9CBD9EBCD559256  electric_bike  01-01-2023 00:05  01-01-2023 00:16
# 2  0514F0FDDA83CC2D   classic_bike  01-01-2023 00:05  01-01-2023 00:32
# 3  BD93FC917AE9F223   classic_bike  01-01-2023 00:06  01-01-2023 00:38
# 4  179364770202D6D8   classic_bike  01-01-2023 00:06  01-01-2023 00:37
#
#   ride_length                       start_station_name  start_station_id  \
# 0    00:37:35                         Lincoln Memorial             31258
# 1    00:11:01                     14th & Belmont St NW             31119
# 2    00:27:08                         Lincoln Memorial             31258
# 3    00:31:57  Court House Metro / 15th St & N Uhle St             31089
# 4    00:30:22  Court House Metro / 15th St & N Uhle St             31089
#
#            end_station_name  end_station_id  start_lat  ...  year  start_hour  \
# 0            20th & E St NW           31204  38.888255  ...  2023           0
# 1       16th & Irving St NW           31122  38.921118  ...  2023           0
# 2     S Troy St & 26th St S           31056  38.888255  ...  2023           0
# 3  Wilson Blvd & Ft Myer Dr           31015  38.890612  ...  2023           0
# 4  Wilson Blvd & Ft Myer Dr           31015  38.890612  ...  2023           0
#
#    end_hour day  day of week  date_is_weekend  trip_duration  time_of_day  \
# 0         0   1       Sunday                0           2255        Night
# 1         0   1       Sunday                0            661        Night
# 2         0   1       Sunday                0           1628        Night
# 3         0   1       Sunday                0           1917        Night
# 4         0   1       Sunday                0           1822        Night
#
#    trip_duration_min    Month
# 0                 38  January
# 1                 11  January
# 2                 27  January
# 3                 32  January
# 4                 30  January
#
# [5 rows x 25 columns]

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=Year23, 
            x="rideable_type", 
            hue="member_casual")
plt.title("Type of bicycles" , fontweight= 'bold')
plt.ylabel ('Number of riders')
plt.show()

# %%
# Ride Frequency
ride_counts = Year23['member_casual'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(ride_counts, labels=ride_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Member Type")
plt.show()
print(ride_counts)
# Out:
# member_casual
# member    671746
# casual    376829
# Name: count, dtype: int64

# %%
member_start = Year23[Year23['member_casual'] == 'member']['start_station_name'].value_counts().head(10)
casual_start = Year23[Year23['member_casual'] == 'casual']['start_station_name'].value_counts().head(10)
member_destination = Year23[Year23['member_casual'] == 'member']['end_station_name'].value_counts().head(10)
casual_destination = Year23[Year23['member_casual'] == 'casual']['end_station_name'].value_counts().head(10)

# %%
plt.bar(member_start.index,member_start, color = "#75b2ce" )
plt.xticks(rotation = 45, ha = 'right')
plt.title("The top 10 start stations of 'member' riders", fontweight="bold")
# labels for the x and y axes
plt.xlabel('Start station')
plt.ylabel ('Number of riders')
plt.show()

print ("The top 10 start stations of 'member' riders")
member_start
# Out:
# The top 10 start stations of 'member' riders
# start_station_name
# Columbus Circle / Union Station                        8850
# New Hampshire Ave & T St NW                            8582
# 15th & P St NW                                         7876
# 5th & K St NW                                          7166
# 1st & M St NE                                          6482
# 14th & V St NW                                         6446
# 17th & Corcoran St NW                                  6102
# Eastern Market Metro / Pennsylvania Ave & 8th St SE    6052
# 8th & O St NW                                          5833
# Massachusetts Ave & Dupont Circle NW                   5634
# Name: count, dtype: int64

# %%
#The top 10 start station of 'casual' riders"
plt.bar(casual_start.index,casual_start, color = "#75b2ce")
plt.xticks(rotation = 45, ha = 'right')
plt.title("The top 10 start stations of 'casual' riders", fontweight="bold")
# labels for the x and y axes
plt.xlabel('Start station')
plt.ylabel ('Number of casual riders')
plt.show()
print("The top 10 start stations of 'casual' riders")
casual_start
# Out:
# The top 10 start stations of 'casual' riders
# start_station_name
# Lincoln Memorial                                         7679
# Jefferson Dr & 14th St SW                                6816
# Smithsonian-National Mall / Jefferson Dr & 12th St SW    6477
# Henry Bacon Dr & Lincoln Memorial Circle NW              6158
# 4th St & Madison Dr NW                                   5789
# 17th St & Independence Ave SW                            4365
# Jefferson Memorial                                       4302
# Columbus Circle / Union Station                          3644
# 15th St & Constitution Ave NW                            3239
# Ohio Dr & West Basin Dr SW / MLK & FDR Memorials         3025
# Name: count, dtype: int64

# %%
#The top 10 destination stations of member riders
plt.bar(member_destination.index, member_destination, color = "#e7f56a")
plt.xticks(rotation = 45, ha = 'right')
plt.title("The top 10 destination stations of member riders", fontweight="bold")
# labels for the x and y axes
plt.xlabel('Destination station')
plt.ylabel ('Number of member riders')
plt.show()
print("The top 10 destination stations of member riders")
# Out:
# The top 10 destination stations of member riders

# %%
#The top 10 destination station of 'casual' riders
plt.bar(casual_destination.index,casual_destination, color = "#75b2ce")
plt.xticks(rotation = 45, ha = 'right')
plt.title("The top 10 destination stations of 'casual' riders", fontweight="bold")
# labels for the x and y axes
plt.xlabel('Destination station')
plt.ylabel ('Number of member riders')
plt.show()

print ("The top 10 destination stations for 'casual' riders")
casual_destination
# Out:
# The top 10 destination stations for 'casual' riders
# end_station_name
# Lincoln Memorial                                         7436
# Jefferson Dr & 14th St SW                                6897
# Smithsonian-National Mall / Jefferson Dr & 12th St SW    6473
# Henry Bacon Dr & Lincoln Memorial Circle NW              5972
# 4th St & Madison Dr NW                                   5143
# Jefferson Memorial                                       4334
# 17th St & Independence Ave SW                            4221
# Columbus Circle / Union Station                          3849
# 15th St & Constitution Ave NW                            3300
# 15th St & Pennsylvania Ave NW                            3184
# Name: count, dtype: int64

# %%
# #Replace int value to String name for weekday
# label_weekdays = ["Sun", "Mon", "Tue", "Wed", "Thu", "Fri, Sat"]
# day = [1, 2, 3, 4, 5, 6, 7]
# Year23['weekdays_str'] = Year23['day'].replace('weekdays,label_weekdays')
# palette = ['#75b2ce', '#e7f56a']
# sns.set()
plt.figure(figsize=(8, 6))
#Plot the graph
ax = sns.countplot(
    data=Year23, 
    x="day of week", 
    hue="member_casual")

# title to the chart
plt.title('The number of rides each day.',fontweight="bold")
plt.ylabel ('Number of riders')
plt.xlabel('weekdays')
plt.show()

# %%
Year23
# Out:
#                   ride_id  rideable_type        started_at          ended_at  \
# 0        4B88BE3AEA4FD3C2   classic_bike  01-01-2023 00:03  01-01-2023 00:41
# 1        B9CBD9EBCD559256  electric_bike  01-01-2023 00:05  01-01-2023 00:16
# 2        0514F0FDDA83CC2D   classic_bike  01-01-2023 00:05  01-01-2023 00:32
# 3        BD93FC917AE9F223   classic_bike  01-01-2023 00:06  01-01-2023 00:38
# 4        179364770202D6D8   classic_bike  01-01-2023 00:06  01-01-2023 00:37
# ...                   ...            ...               ...               ...
# 1048570  B270F52960092ED9   classic_bike  05-05-2023 18:34  05-05-2023 18:42
# 1048571  112ABBEEEF52EB1F   classic_bike  05-05-2023 18:34  05-05-2023 18:43
# 1048572  EF5E242CDA10F657   classic_bike  05-05-2023 18:34  05-05-2023 18:47
# 1048573  6C367E8734F915B7   classic_bike  05-05-2023 18:34  05-05-2023 18:49
# 1048574  54956737ACE50C23   classic_bike  05-05-2023 18:34  05-05-2023 18:38
#
#         ride_length                                 start_station_name  \
# 0          00:37:35                                   Lincoln Memorial
# 1          00:11:01                               14th & Belmont St NW
# 2          00:27:08                                   Lincoln Memorial
# 3          00:31:57            Court House Metro / 15th St & N Uhle St
# 4          00:30:22            Court House Metro / 15th St & N Uhle St
# ...             ...                                                ...
# 1048570    00:08:33                                     15th & L St NW
# 1048571    00:08:45                                     15th & P St NW
# 1048572    00:12:56                      19th St & Pennsylvania Ave NW
# 1048573    00:14:49                                     15th & P St NW
# 1048574    00:04:19  Eastern Market Metro / Pennsylvania Ave & 8th ...
#
#          start_station_id                           end_station_name  \
# 0                   31258                             20th & E St NW
# 1                   31119                        16th & Irving St NW
# 2                   31258                      S Troy St & 26th St S
# 3                   31089                   Wilson Blvd & Ft Myer Dr
# 4                   31089                   Wilson Blvd & Ft Myer Dr
# ...                   ...                                        ...
# 1048570             31276                             15th & L St NW
# 1048571             31201                             18th & R St NW
# 1048572             31100  7th & F St NW / National Portrait Gallery
# 1048573             31201                  13th St & New York Ave NW
# 1048574             31613  Lincoln Park / 13th & East Capitol St NE
#
#          end_station_id  start_lat  ...  year  start_hour  end_hour day  \
# 0                 31204  38.888255  ...  2023           0         0   1
# 1                 31122  38.921118  ...  2023           0         0   1
# 2                 31056  38.888255  ...  2023           0         0   1
# 3                 31015  38.890612  ...  2023           0         0   1
# 4                 31015  38.890612  ...  2023           0         0   1
# ...                 ...        ...  ...   ...         ...       ...  ..
# 1048570           31276  38.903649  ...  2023          18        18   5
# 1048571           31278  38.909801  ...  2023          18        18   5
# 1048572           31232  38.900300  ...  2023          18        18   5
# 1048573           31227  38.909801  ...  2023          18        18   5
# 1048574           31619  38.884095  ...  2023          18        18   5
#
#          day of week  date_is_weekend  trip_duration  time_of_day  \
# 0             Sunday                0           2255        Night
# 1             Sunday                0            661        Night
# 2             Sunday                0           1628        Night
# 3             Sunday                0           1917        Night
# 4             Sunday                0           1822        Night
# ...              ...              ...            ...          ...
# 1048570       Friday                0            513      Evening
# 1048571       Friday                0            525      Evening
# 1048572       Friday                0            776      Evening
# 1048573       Friday                0            889      Evening
# 1048574       Friday                0            259      Evening
#
#          trip_duration_min    Month
# 0                       38  January
# 1                       11  January
# 2                       27  January
# 3                       32  January
# 4                       30  January
# ...                    ...      ...
# 1048570                  9      May
# 1048571                  9      May
# 1048572                 13      May
# 1048573                 15      May
# 1048574                  4      May
#
# [1048575 rows x 25 columns]

# %%
# Hourly ridership comparison
plt.figure(figsize=(10, 5))
sns.countplot(x='Month', hue='member_casual', data=Year23)
plt.xlabel('Month')
plt.ylabel('Total Rides')
plt.title('Monthly Rides by Member Type')
plt.show()
