# %%
import numpy as np
import folium
from folium import plugins
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("Full_cleaned.csv")

# %%
m=folium.Map()
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d56d66743d876d6a5efc6a612c614cac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d56d66743d876d6a5efc6a612c614cac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d56d66743d876d6a5efc6a612c614cac = L.map(
#                 &quot;map_d56d66743d876d6a5efc6a612c614cac&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24ccf6cfd9835e6faf89ebab3bd06a44 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_24ccf6cfd9835e6faf89ebab3bd06a44.addTo(map_d56d66743d876d6a5efc6a612c614cac);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# After that, we can immediately set on creating a map
m=folium.Map()

# By default it will show the world map zoomed out all the way. We can
# remedy that by passing arguments.

m=folium.Map(location=[38.880440 , -77.025236],   # Our map view centrepoint. In our case, Berlin.
                zoom_start=12,              # Starting zoom step
                max_zoom=26,                # Maximum zooming step
                min_zoom=2)   
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96d7e0fc2de876ed8b951d97485ccd12 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96d7e0fc2de876ed8b951d97485ccd12&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_96d7e0fc2de876ed8b951d97485ccd12 = L.map(
#                 &quot;map_96d7e0fc2de876ed8b951d97485ccd12&quot;,
#                 {
#                     center: [38.88044, -77.025236],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_26a0bffdce2bf9aaabf91e2f405800c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 2,
#   &quot;maxZoom&quot;: 26,
#   &quot;maxNativeZoom&quot;: 26,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_26a0bffdce2bf9aaabf91e2f405800c5.addTo(map_96d7e0fc2de876ed8b951d97485ccd12);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Top 15 Start Stations and Bike Usages with Stations

# %%
# Top 15 Start Stations
m=folium.Map(location=[ 38.889805, -77.009056 ], zoom_start=12, min_zoom=9)
# We will add a marker at the specified coordinates 
folium.Marker([38.915544, -77.038252], popup ="New Hampshire Ave & T St NW -102179").add_to(m)
folium.Marker([38.89696, -77.00493], popup ="Columbus Circle / Union Station -100584").add_to(m)
folium.Marker([38.888255, -77.0494365], popup ="Lincoln Memorial -96667").add_to(m)
folium.Marker([38.909892, -77.034337], popup ="15th & P St NW -95670").add_to(m)
folium.Marker([38.888553, -77.032427], popup ="Jefferson Dr & 14th St SW -88078").add_to(m)
folium.Marker([38.905746, -77.005568], popup ="1st & M St NE -85552").add_to(m)
folium.Marker([38.8904955, -77.0172465], popup ="4th St & Madison Dr NW -83831").add_to(m)
folium.Marker([38.90304, -77.019027], popup ="5th & K St NW -76586").add_to(m)
folium.Marker([38.888774, -77.028694], popup ="Smithsonian-National Mall / Jefferson Dr & 12th St SW -76452").add_to(m)
folium.Marker([38.890539, -77.049383], popup ="Henry Bacon Dr & Lincoln Memorial Circle NW -76236").add_to(m)
folium.Marker([38.9177645, -77.032096], popup ="14th & V St NW -75868").add_to(m) 
folium.Marker([38.88426009, -76.9947356], popup ="Eastern Market Metro / Pennsylvania Ave & 8th St SE -75397").add_to(m)
folium.Marker([38.91012967, -77.04420567], popup ="Massachusetts Ave & Dupont Circle NW -72609").add_to(m)
folium.Marker([38.90864, -77.02277], popup ="8th & O St NW -68040").add_to(m)
folium.Marker([38.913046, -77.032008], popup ="14th & R St NW -67332").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bacb7f78c39ecb2387dff7f3a00f0786 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bacb7f78c39ecb2387dff7f3a00f0786&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bacb7f78c39ecb2387dff7f3a00f0786 = L.map(
#                 &quot;map_bacb7f78c39ecb2387dff7f3a00f0786&quot;,
#                 {
#                     center: [38.889805, -77.009056],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d01e5f2031a53c8c4cbdf3fff221518f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 9,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d01e5f2031a53c8c4cbdf3fff221518f.addTo(map_bacb7f78c39ecb2387dff7f3a00f0786);
#
#
#             var marker_7e1c64648ddaaa399700d44e2a46236a = L.marker(
#                 [38.915544, -77.038252],
#                 {
# }
#             ).addTo(map_bacb7f78c39ecb2387dff7f3a00f0786);
#
#
#         var popup_46ed0dae28ab0773eeb18c402416861e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc9bb0b373ee41692c3d74ead939d8d6 = $(`&lt;div id=&quot;html_dc9bb0b373ee41692c3d74ead939d8d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New Hampshire Ave &amp; T St NW -102179&lt;/div&gt;`)[0];
#                 popup_46ed0dae28ab0773eeb18c402416861e.setContent(html_dc9bb0b373ee41692c3d74ead939d8d6);
#
#
#
#         marker_7e1c64648ddaaa399700d44e2a46236a.bindPopup(popup_46ed0dae28ab0773eeb18c402416861e)
#         ;
#
#
#
#
#             var marker_59ce525fc4b024840800a6c8a3527f1a = L.marker(
#                 [38.89696, -77.00493],
#                 {
# }
#             ).addTo(map_bacb7f78c39ecb2387dff7f3a00f0786);
#
#
#         var popup_79b0ca1e4852d1f46f90cd7d35378818 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b49e78498b288445772262a9073addf1 = $(`&lt;div id=&quot;html_b49e78498b288445772262a9073addf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Columbus Circle / Union Station -100584&lt;/div&gt;`)[0];
#                 popup_79b0ca1e4852d1f46f90cd7d35378818.setContent(html_b49e78498b288445772262a9073addf1);
#
#
#
#         marker_59ce525fc4b024840800a6c8a3527f1a.bindPopup(popup_79b0ca1e4852d1f46f90cd7d35378818)
#         ;
#
#
#
#
#             var marker_5f97c490459b9079dfe68e75a31dd5ea = L.marker(
#                 [38.888255, -77.0494365],
#                 {
# }
#             ).addTo(map_bacb7f78c39ecb2387dff7f3a00f0786);
#
#
#         var popup_790e247ca12ac5f167273ad7e7a99dc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1709657cddb9b11d25b63ca9991be1c4 = $(`&lt;div id=&quot;html_1709657cddb9b11d25b63ca9991be1c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lincoln Memorial -96667&lt;/div&gt;`)[0];
#                 popup_790e247ca12ac5f167273ad7e7a99dc2.setContent(html_1709657cddb9b11d25b63ca9991be1c4);
#
#
#
#         marker_5f97c490459b9079dfe68e75a31dd5ea.bindPopup(popup_790e247ca12ac5f167273ad7e7a99dc2)
#         ;
#
#
#
#
#             var marker_9eda843a17c500a77de83de22a89721b = L.marker(
#                 [38.909892, -77.034337],
#                 {
# }
#             ).addTo(map_bacb7f78c39ecb2387dff7f3a00f0786);
#
#
#         var popup_5cc4d604a32efbddd8a97a70234bec50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39f46b5583c2c2f48861dc8afefd5c7f = $(`&lt;div id=&quot;html_39f46b5583c2c2f48861dc8afefd5c7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;15th &amp; P St NW -95670&lt;/div&gt;`)[0];
#                 popup_5cc4d604a32efbddd8a97a70234bec50.setContent(html_39f46b5583c2c2f48861dc8afefd5c7f);
#
#
#
#         marker_9eda843a17c500a77de83de22a89721b.bindPopup(popup_5cc4d604a32efbddd8a97a70234bec50)
#         ;
#
#
#
#
#             var marker_8f383c38752fcf40891a8be66d318eb5 = L.marker(
#                 [38.888553, -77.032427],
#                 {
# }
#             ).addTo(map_bacb7f78c39ecb2387dff7f3a00f0786);
#
#
#         var popup_fc6e01487fb4a3f2f96526b2f67f6b5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a5bb6a6b33527e9581202acd1b804b8 = $(`&lt;div id=&quot;html_4a5bb6a6b33527e9581202acd1b804b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jefferson Dr &amp; 14th St SW -88078&lt;/div&gt;`)[0];
#                 popup_fc6e01487fb4a3f2f96526b2f67f6b5a.setContent(html_4a5bb6a6b33527e9581202acd1b804b8);
#
#
#
#         marker_8f383c38752fcf40891a8be66d318eb5.bindPopup(popup_fc6e01487fb4a3f2f96526b2f67f6b5a)
#         ;
#
#
#
#
#             var marke

# %%
# Top 15 End Stations
m=folium.Map(location=[ 38.889805, -77.009056 ], zoom_start=12, min_zoom=9)
# We will add a marker at the specified coordinates 
folium.Marker([38.89696, -77.00493], popup ="Columbus Circle / Union Station -102410").add_to(m)
folium.Marker([38.915544, -77.038252], popup ="New Hampshire Ave & T St NW -100880").add_to(m)
folium.Marker([38.90980063, -77.03442693], popup ="15th & P St NW -96758").add_to(m)
folium.Marker([38.888255, -77.049437], popup ="Lincoln Memorial -95439").add_to(m)
folium.Marker([38.8885525, -77.032427], popup ="Jefferson Dr & 14th St SW -91470").add_to(m)
folium.Marker([38.905697, -77.005483], popup ="1st & M St NE -87083").add_to(m)
folium.Marker([38.8904955, -77.0172465], popup ="4th St & Madison Dr NW -83007").add_to(m)
folium.Marker([38.888774, -77.028694], popup ="Smithsonian-National Mall / Jefferson Dr & 12th St SW - 78897").add_to(m)
folium.Marker([38.9101, -77.0444], popup ="Massachusetts Ave & Dupont Circle NW -78765").add_to(m)
folium.Marker([38.90304, -77.019027], popup ="5th & K St NW -77980").add_to(m)
folium.Marker([38.890539, -77.049383], popup ="Henry Bacon Dr & Lincoln Memorial Circle NW -76505").add_to(m)
folium.Marker([38.88411367, -76.995287], popup ="Eastern Market Metro / Pennsylvania Ave & 8th St SE -76294").add_to(m)
folium.Marker([38.9177645, -77.032096], popup ="14th & V St NW - 75120").add_to(m)
folium.Marker([38.91299117, -77.03186733], popup ="14th & R St NW -68771").add_to(m)
folium.Marker([38.90864, -77.02277], popup ="8th & O St NW - 67898").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4fce3e24ae44ebb5e5550e353fe8b882 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4fce3e24ae44ebb5e5550e353fe8b882&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4fce3e24ae44ebb5e5550e353fe8b882 = L.map(
#                 &quot;map_4fce3e24ae44ebb5e5550e353fe8b882&quot;,
#                 {
#                     center: [38.889805, -77.009056],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f40a4347b72b418cd1d29a6d9c24cefe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 9,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f40a4347b72b418cd1d29a6d9c24cefe.addTo(map_4fce3e24ae44ebb5e5550e353fe8b882);
#
#
#             var marker_140b3e0f3b53ad32dae2d642d9186a3c = L.marker(
#                 [38.89696, -77.00493],
#                 {
# }
#             ).addTo(map_4fce3e24ae44ebb5e5550e353fe8b882);
#
#
#         var popup_67af3089d1ee04c2f8f7194fd160ed0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f04b9d45f3392916564a8f2aca4c5035 = $(`&lt;div id=&quot;html_f04b9d45f3392916564a8f2aca4c5035&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Columbus Circle / Union Station -102410&lt;/div&gt;`)[0];
#                 popup_67af3089d1ee04c2f8f7194fd160ed0c.setContent(html_f04b9d45f3392916564a8f2aca4c5035);
#
#
#
#         marker_140b3e0f3b53ad32dae2d642d9186a3c.bindPopup(popup_67af3089d1ee04c2f8f7194fd160ed0c)
#         ;
#
#
#
#
#             var marker_d9f2446b18706b07f53e6400e34c8677 = L.marker(
#                 [38.915544, -77.038252],
#                 {
# }
#             ).addTo(map_4fce3e24ae44ebb5e5550e353fe8b882);
#
#
#         var popup_fc90071dc9ad356174890816d03cc477 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73a32ecf632273ce443fbe592ad51add = $(`&lt;div id=&quot;html_73a32ecf632273ce443fbe592ad51add&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New Hampshire Ave &amp; T St NW -100880&lt;/div&gt;`)[0];
#                 popup_fc90071dc9ad356174890816d03cc477.setContent(html_73a32ecf632273ce443fbe592ad51add);
#
#
#
#         marker_d9f2446b18706b07f53e6400e34c8677.bindPopup(popup_fc90071dc9ad356174890816d03cc477)
#         ;
#
#
#
#
#             var marker_d733c36431a35a62bfcb9ec1ab9cb523 = L.marker(
#                 [38.90980063, -77.03442693],
#                 {
# }
#             ).addTo(map_4fce3e24ae44ebb5e5550e353fe8b882);
#
#
#         var popup_84fe4cb2e0362199fa485529bc185639 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8911442e115fdbfd267f77b992bc1a59 = $(`&lt;div id=&quot;html_8911442e115fdbfd267f77b992bc1a59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;15th &amp; P St NW -96758&lt;/div&gt;`)[0];
#                 popup_84fe4cb2e0362199fa485529bc185639.setContent(html_8911442e115fdbfd267f77b992bc1a59);
#
#
#
#         marker_d733c36431a35a62bfcb9ec1ab9cb523.bindPopup(popup_84fe4cb2e0362199fa485529bc185639)
#         ;
#
#
#
#
#             var marker_20bff0131be4f78400968f274f0439ed = L.marker(
#                 [38.888255, -77.049437],
#                 {
# }
#             ).addTo(map_4fce3e24ae44ebb5e5550e353fe8b882);
#
#
#         var popup_f8205c160939039afb8931e6108c4e90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7c0efc7705b71e1df86ae2602e4155a = $(`&lt;div id=&quot;html_d7c0efc7705b71e1df86ae2602e4155a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lincoln Memorial -95439&lt;/div&gt;`)[0];
#                 popup_f8205c160939039afb8931e6108c4e90.setContent(html_d7c0efc7705b71e1df86ae2602e4155a);
#
#
#
#         marker_20bff0131be4f78400968f274f0439ed.bindPopup(popup_f8205c160939039afb8931e6108c4e90)
#         ;
#
#
#
#
#             var marker_0af36c0ce7d7773bb6c66aabf1b4a0b8 = L.marker(
#                 [38.8885525, -77.032427],
#                 {
# }
#             ).addTo(map_4fce3e24ae44ebb5e5550e353fe8b882);
#
#
#         var popup_e4d1e02d6e9f9ab2c1f502a5f00e0db5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5462f44b505b321e1fad08f35ba0e298 = $(`&lt;div id=&quot;html_5462f44b505b321e1fad08f35ba0e298&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jefferson Dr &amp; 14th St SW -91470&lt;/div&gt;`)[0];
#                 popup_e4d1e02d6e9f9ab2c1f502a5f00e0db5.setContent(html_5462f44b505b321e1fad08f35ba0e298);
#
#
#
#         marker_0af36c0ce7d7773bb6c66aabf1b4a0b8.bindPopup(popup_e4d1e02d6e9f9ab2c1f502a5f00e0db5)
#         ;
#
#
#
#
#             var m

# %%
# # Find the top 10 stations with the highest number of trips in 2023
# top_stations = (df.groupby('start_station_name', observed=False).agg(trip_count=('ride_id', 'count')).nlargest(10, 'trip_count')
#     .reset_index()
# )

# # Merge with stations dataframe to get latitude and longitude
# top_stations_2023 = top_stations.merge(stations, left_on='start_station_name', right_on='station')

# %%
import pandas as pd
import numpy as np
# ... (your other imports and create_heatmap function)

# Inspect dtypes
print(df.dtypes)
print(all_locations.dtypes)

# Inspect for NaNs after conversion
print(all_locations.isna().sum())  # How many NaN values in each column?

# Inspect specific columns for non-numeric or unexpected values
print(df['start_lat'].unique()) # Check for non-numeric values
print(df['start_lng'].unique())
print(df['end_lat'].unique())
print(df['end_lng'].unique())

print(all_locations['lat'].unique()) # Check after concat and rename
print(all_locations['lng'].unique())
print(all_locations['count'].unique())

# Check for infinite values (np.inf, -np.inf)
print(np.isinf(all_locations['lat']).any())
print(np.isinf(all_locations['lng']).any())
print(np.isinf(all_locations['count']).any())
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id      float64
# end_station_name       object
# end_station_id        float64
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# Month                  object
# year                    int64
# start_hour              int64
# end_hour                int64
# day                     int64
# day of week            object
# date_is_weekend         int64
# trip_duration         float64
# time_of_day            object
# Season                 object
# distance              float64
# dtype: object
# lat      float64
# lng      float64
# count      int64
# dtype: object
# lat      0
# lng      0
# count    0
# dtype: int64
# [38.88044    38.9121375  38.87947661 ... 38.89827919 38.80470359
#  38.88418543]
# [-77.025236   -77.03856817 -77.11456329 ... -77.02627075 -77.02619064
#  -77.03884649]
# [38.8946     38.9208705  38.87947661 ... 38.88143586 38.8685447
#  38.91898809]
# [-77.072305   -77.03169117 -77.11456329 ... -77.23037748 -77.28208338
#  -77.21245961]
# [38.782551   38.78255165 38.78255483 ... 39.123471   39.12348017
#  39.12349283]
# [-77.01606783 -77.01601577 -77.01569417 ... -77.157443   -77.15743067
#  -77.1574165 ]
# [   1 1859 6472 ... 1145  607  350]
# False
# False
# False

# %%
from folium.plugins import HeatMap
# Create a map centered around the data
map_center = [df['start_lat'].mean(), df['start_lng'].mean()]
heat_map = folium.Map(location=map_center, zoom_start=12)

# Prepare start and end locations with counts
start_locations = df.groupby(['start_lat', 'start_lng']).size().reset_index()
start_locations.columns = ['lat', 'lng', 'count']

end_locations = df.groupby(['end_lat', 'end_lng']).size().reset_index()
end_locations.columns = ['lat', 'lng', 'count']

# Combine start and end locations
all_locations = pd.concat([start_locations, end_locations])

# Filter out rows with NaN values and convert to list of lists
heat_data = all_locations.dropna(subset=['lat', 'lng']).astype(float).values.tolist()

# Add the heatmap layer
HeatMap(
    data=heat_data,
    radius=8,
    max_zoom=13,
    min_opacity=0.5,
    blur=5
).add_to(heat_map)

# Display the map
heat_map
heat_map.save("bike_heatmap.html")

# %%
# Compute the map center based on mean latitude and longitude
map_center = [top_stations['lat'].mean(), top_stations['lng'].mean()]
top_stations_map = folium.Map(location=map_center, zoom_start=12)

# Add GeoJSON layers
folium.GeoJson("Neighborhood_Planning_Areas.geojson", name="Neighborhood").add_to(top_stations_map)
folium.GeoJson("Wards_from_2012.geojson", name="Wards").add_to(top_stations_map)
folium.GeoJson("Capital_Bikeshare_Locations.geojson", name="Capital_Bike_Share").add_to(top_stations_map)
folium.GeoJson("Metro_Bus_Lines.geojson", name="Bus_route").add_to(top_stations_map)


# Add markers for the top 10 stations
for _, row in top_stations_2023.iterrows():
    folium.Marker(
        location=[row['lat'], row['lng']],
        popup=folium.Popup(f"{row['start_station_name']} ({row['trip_count']} trips)", max_width=250),
        icon=folium.Icon(color='blue', icon='bicycle', prefix='fa')
    ).add_to(top_stations_map)

# Add layer control for toggling layers
folium.LayerControl().add_to(top_stations_map)

# Display map
top_stations_map
