# %%
import numpy as np
import folium
from folium import plugins
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("Full_cleaned.csv")

# %%
m=folium.Map()
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b60e96875f1be30290448e8ea65cef0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b60e96875f1be30290448e8ea65cef0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b60e96875f1be30290448e8ea65cef0 = L.map(
#                 &quot;map_2b60e96875f1be30290448e8ea65cef0&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21df13f4c75dc4338b30cabe5ae00cb6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_21df13f4c75dc4338b30cabe5ae00cb6.addTo(map_2b60e96875f1be30290448e8ea65cef0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# After that, we can immediately set on creating a map
m=folium.Map()

# By default it will show the world map zoomed out all the way. We can
# remedy that by passing arguments.

m=folium.Map(location=[38.880440 , -77.025236],   # Our map view centrepoint. In our case, Berlin.
                zoom_start=12,              # Starting zoom step
                max_zoom=26,                # Maximum zooming step
                min_zoom=2)   
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93b8e6c1911e5a0f2929a1d97a3cb6f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93b8e6c1911e5a0f2929a1d97a3cb6f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93b8e6c1911e5a0f2929a1d97a3cb6f6 = L.map(
#                 &quot;map_93b8e6c1911e5a0f2929a1d97a3cb6f6&quot;,
#                 {
#                     center: [38.88044, -77.025236],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db8a3e1645c870c72e7f0defe81447f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 2,
#   &quot;maxZoom&quot;: 26,
#   &quot;maxNativeZoom&quot;: 26,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db8a3e1645c870c72e7f0defe81447f5.addTo(map_93b8e6c1911e5a0f2929a1d97a3cb6f6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Top 15 Start Stations and Bike Usages with Stations

# %%
# Top 15 Start Stations
m=folium.Map(location=[ 38.889805, -77.009056 ], zoom_start=12, min_zoom=9)
# We will add a marker at the specified coordinates 
folium.Marker([38.915544, -77.038252], popup ="New Hampshire Ave & T St NW -102179").add_to(m)
folium.Marker([38.89696, -77.00493], popup ="Columbus Circle / Union Station -100584").add_to(m)
folium.Marker([38.888255, -77.0494365], popup ="Lincoln Memorial -96667").add_to(m)
folium.Marker([38.909892, -77.034337], popup ="15th & P St NW -95670").add_to(m)
folium.Marker([38.888553, -77.032427], popup ="Jefferson Dr & 14th St SW -88078").add_to(m)
folium.Marker([38.905746, -77.005568], popup ="1st & M St NE -85552").add_to(m)
folium.Marker([38.8904955, -77.0172465], popup ="4th St & Madison Dr NW -83831").add_to(m)
folium.Marker([38.90304, -77.019027], popup ="5th & K St NW -76586").add_to(m)
folium.Marker([38.888774, -77.028694], popup ="Smithsonian-National Mall / Jefferson Dr & 12th St SW -76452").add_to(m)
folium.Marker([38.890539, -77.049383], popup ="Henry Bacon Dr & Lincoln Memorial Circle NW -76236").add_to(m)
folium.Marker([38.9177645, -77.032096], popup ="14th & V St NW -75868").add_to(m) 
folium.Marker([38.88426009, -76.9947356], popup ="Eastern Market Metro / Pennsylvania Ave & 8th St SE -75397").add_to(m)
folium.Marker([38.91012967, -77.04420567], popup ="Massachusetts Ave & Dupont Circle NW -72609").add_to(m)
folium.Marker([38.90864, -77.02277], popup ="8th & O St NW -68040").add_to(m)
folium.Marker([38.913046, -77.032008], popup ="14th & R St NW -67332").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_578f119f947afe894b1b1377baa741d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_578f119f947afe894b1b1377baa741d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_578f119f947afe894b1b1377baa741d8 = L.map(
#                 &quot;map_578f119f947afe894b1b1377baa741d8&quot;,
#                 {
#                     center: [38.889805, -77.009056],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0fa37a9b2d78e2b75e9d0a9240c7931 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 9,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0fa37a9b2d78e2b75e9d0a9240c7931.addTo(map_578f119f947afe894b1b1377baa741d8);
#
#
#             var marker_3ea831045c49b1f8347a79caa682603d = L.marker(
#                 [38.915544, -77.038252],
#                 {
# }
#             ).addTo(map_578f119f947afe894b1b1377baa741d8);
#
#
#         var popup_0bc90e81f4c678e7a2c7e1bcd0210b7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87b15af214b22e5973f77fb1444cfe9a = $(`&lt;div id=&quot;html_87b15af214b22e5973f77fb1444cfe9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New Hampshire Ave &amp; T St NW -102179&lt;/div&gt;`)[0];
#                 popup_0bc90e81f4c678e7a2c7e1bcd0210b7e.setContent(html_87b15af214b22e5973f77fb1444cfe9a);
#
#
#
#         marker_3ea831045c49b1f8347a79caa682603d.bindPopup(popup_0bc90e81f4c678e7a2c7e1bcd0210b7e)
#         ;
#
#
#
#
#             var marker_70f462260c6589385ef90b548d18532a = L.marker(
#                 [38.89696, -77.00493],
#                 {
# }
#             ).addTo(map_578f119f947afe894b1b1377baa741d8);
#
#
#         var popup_d38fb6b0f8d1bb14b996581871ac416d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bed0a3efdcb1db9dcfbdb94694ce5daf = $(`&lt;div id=&quot;html_bed0a3efdcb1db9dcfbdb94694ce5daf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Columbus Circle / Union Station -100584&lt;/div&gt;`)[0];
#                 popup_d38fb6b0f8d1bb14b996581871ac416d.setContent(html_bed0a3efdcb1db9dcfbdb94694ce5daf);
#
#
#
#         marker_70f462260c6589385ef90b548d18532a.bindPopup(popup_d38fb6b0f8d1bb14b996581871ac416d)
#         ;
#
#
#
#
#             var marker_dc4e0eacc22a16ac52cd10456b399f53 = L.marker(
#                 [38.888255, -77.0494365],
#                 {
# }
#             ).addTo(map_578f119f947afe894b1b1377baa741d8);
#
#
#         var popup_6eb74fb4722f019e003255c608a79a9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7625196508ff6db5051e5c120a5ea1b2 = $(`&lt;div id=&quot;html_7625196508ff6db5051e5c120a5ea1b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lincoln Memorial -96667&lt;/div&gt;`)[0];
#                 popup_6eb74fb4722f019e003255c608a79a9e.setContent(html_7625196508ff6db5051e5c120a5ea1b2);
#
#
#
#         marker_dc4e0eacc22a16ac52cd10456b399f53.bindPopup(popup_6eb74fb4722f019e003255c608a79a9e)
#         ;
#
#
#
#
#             var marker_b702cfdef91f1b9ec8ac4950d8d479e6 = L.marker(
#                 [38.909892, -77.034337],
#                 {
# }
#             ).addTo(map_578f119f947afe894b1b1377baa741d8);
#
#
#         var popup_1797365e570eceb533ddd7eb93d60768 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef33724dbc8a55e66ce9ec8ed1134c91 = $(`&lt;div id=&quot;html_ef33724dbc8a55e66ce9ec8ed1134c91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;15th &amp; P St NW -95670&lt;/div&gt;`)[0];
#                 popup_1797365e570eceb533ddd7eb93d60768.setContent(html_ef33724dbc8a55e66ce9ec8ed1134c91);
#
#
#
#         marker_b702cfdef91f1b9ec8ac4950d8d479e6.bindPopup(popup_1797365e570eceb533ddd7eb93d60768)
#         ;
#
#
#
#
#             var marker_80b06a943479918f16a62bdfa045063c = L.marker(
#                 [38.888553, -77.032427],
#                 {
# }
#             ).addTo(map_578f119f947afe894b1b1377baa741d8);
#
#
#         var popup_3b898d88d61b865c48665f0962548139 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42c431be6dad97299ba280b37e078fe0 = $(`&lt;div id=&quot;html_42c431be6dad97299ba280b37e078fe0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jefferson Dr &amp; 14th St SW -88078&lt;/div&gt;`)[0];
#                 popup_3b898d88d61b865c48665f0962548139.setContent(html_42c431be6dad97299ba280b37e078fe0);
#
#
#
#         marker_80b06a943479918f16a62bdfa045063c.bindPopup(popup_3b898d88d61b865c48665f0962548139)
#         ;
#
#
#
#
#             var marke

# %%
# Top 15 End Stations
m=folium.Map(location=[ 38.889805, -77.009056 ], zoom_start=12, min_zoom=9)
# We will add a marker at the specified coordinates 
folium.Marker([38.89696, -77.00493], popup ="Columbus Circle / Union Station -102410").add_to(m)
folium.Marker([38.915544, -77.038252], popup ="New Hampshire Ave & T St NW -100880").add_to(m)
folium.Marker([38.90980063, -77.03442693], popup ="15th & P St NW -96758").add_to(m)
folium.Marker([38.888255, -77.049437], popup ="Lincoln Memorial -95439").add_to(m)
folium.Marker([38.8885525, -77.032427], popup ="Jefferson Dr & 14th St SW -91470").add_to(m)
folium.Marker([38.905697, -77.005483], popup ="1st & M St NE -87083").add_to(m)
folium.Marker([38.8904955, -77.0172465], popup ="4th St & Madison Dr NW -83007").add_to(m)
folium.Marker([38.888774, -77.028694], popup ="Smithsonian-National Mall / Jefferson Dr & 12th St SW - 78897").add_to(m)
folium.Marker([38.9101, -77.0444], popup ="Massachusetts Ave & Dupont Circle NW -78765").add_to(m)
folium.Marker([38.90304, -77.019027], popup ="5th & K St NW -77980").add_to(m)
folium.Marker([38.890539, -77.049383], popup ="Henry Bacon Dr & Lincoln Memorial Circle NW -76505").add_to(m)
folium.Marker([38.88411367, -76.995287], popup ="Eastern Market Metro / Pennsylvania Ave & 8th St SE -76294").add_to(m)
folium.Marker([38.9177645, -77.032096], popup ="14th & V St NW - 75120").add_to(m)
folium.Marker([38.91299117, -77.03186733], popup ="14th & R St NW -68771").add_to(m)
folium.Marker([38.90864, -77.02277], popup ="8th & O St NW - 67898").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d17034b47b46c976d1e4dcb06f1a494 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d17034b47b46c976d1e4dcb06f1a494&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d17034b47b46c976d1e4dcb06f1a494 = L.map(
#                 &quot;map_6d17034b47b46c976d1e4dcb06f1a494&quot;,
#                 {
#                     center: [38.889805, -77.009056],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea64705b8864ab6f5ce1fb33fb7500f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 9,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ea64705b8864ab6f5ce1fb33fb7500f9.addTo(map_6d17034b47b46c976d1e4dcb06f1a494);
#
#
#             var marker_defe187cf2187327fec9acbfc782293b = L.marker(
#                 [38.89696, -77.00493],
#                 {
# }
#             ).addTo(map_6d17034b47b46c976d1e4dcb06f1a494);
#
#
#         var popup_35f69ab92e1e99dc2535c99e10e967af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17942edc5a376f60c7fac3dcadb0b47d = $(`&lt;div id=&quot;html_17942edc5a376f60c7fac3dcadb0b47d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Columbus Circle / Union Station -102410&lt;/div&gt;`)[0];
#                 popup_35f69ab92e1e99dc2535c99e10e967af.setContent(html_17942edc5a376f60c7fac3dcadb0b47d);
#
#
#
#         marker_defe187cf2187327fec9acbfc782293b.bindPopup(popup_35f69ab92e1e99dc2535c99e10e967af)
#         ;
#
#
#
#
#             var marker_12a3e96545fbc3116f99ea7d45a128f9 = L.marker(
#                 [38.915544, -77.038252],
#                 {
# }
#             ).addTo(map_6d17034b47b46c976d1e4dcb06f1a494);
#
#
#         var popup_e95f62e698fab7efb653753df303bf28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a759bcc4aeb4d109bbe199aedf77760c = $(`&lt;div id=&quot;html_a759bcc4aeb4d109bbe199aedf77760c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New Hampshire Ave &amp; T St NW -100880&lt;/div&gt;`)[0];
#                 popup_e95f62e698fab7efb653753df303bf28.setContent(html_a759bcc4aeb4d109bbe199aedf77760c);
#
#
#
#         marker_12a3e96545fbc3116f99ea7d45a128f9.bindPopup(popup_e95f62e698fab7efb653753df303bf28)
#         ;
#
#
#
#
#             var marker_49bfc7314a8a2d616a72260208669612 = L.marker(
#                 [38.90980063, -77.03442693],
#                 {
# }
#             ).addTo(map_6d17034b47b46c976d1e4dcb06f1a494);
#
#
#         var popup_dec391789d398a1e1f28d766d4f7ddb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91cc20a1003c641abad1482a270e4f29 = $(`&lt;div id=&quot;html_91cc20a1003c641abad1482a270e4f29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;15th &amp; P St NW -96758&lt;/div&gt;`)[0];
#                 popup_dec391789d398a1e1f28d766d4f7ddb3.setContent(html_91cc20a1003c641abad1482a270e4f29);
#
#
#
#         marker_49bfc7314a8a2d616a72260208669612.bindPopup(popup_dec391789d398a1e1f28d766d4f7ddb3)
#         ;
#
#
#
#
#             var marker_a2ea4fd670d860adeed960cd587d36cc = L.marker(
#                 [38.888255, -77.049437],
#                 {
# }
#             ).addTo(map_6d17034b47b46c976d1e4dcb06f1a494);
#
#
#         var popup_0c70ccfca9d82ec2f3fc23fa953cd57a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb97a1eed8972698a4fd447e2311a351 = $(`&lt;div id=&quot;html_bb97a1eed8972698a4fd447e2311a351&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lincoln Memorial -95439&lt;/div&gt;`)[0];
#                 popup_0c70ccfca9d82ec2f3fc23fa953cd57a.setContent(html_bb97a1eed8972698a4fd447e2311a351);
#
#
#
#         marker_a2ea4fd670d860adeed960cd587d36cc.bindPopup(popup_0c70ccfca9d82ec2f3fc23fa953cd57a)
#         ;
#
#
#
#
#             var marker_f762e7d6f3e359d8872d20e033693521 = L.marker(
#                 [38.8885525, -77.032427],
#                 {
# }
#             ).addTo(map_6d17034b47b46c976d1e4dcb06f1a494);
#
#
#         var popup_1b8d5a53eb48c98308562f9fe5baa7a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f9b7fff7cd199276b2d44bf224ec46e = $(`&lt;div id=&quot;html_0f9b7fff7cd199276b2d44bf224ec46e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jefferson Dr &amp; 14th St SW -91470&lt;/div&gt;`)[0];
#                 popup_1b8d5a53eb48c98308562f9fe5baa7a9.setContent(html_0f9b7fff7cd199276b2d44bf224ec46e);
#
#
#
#         marker_f762e7d6f3e359d8872d20e033693521.bindPopup(popup_1b8d5a53eb48c98308562f9fe5baa7a9)
#         ;
#
#
#
#
#             var m

# %%
# # Find the top 10 stations with the highest number of trips in 2023
# top_stations = (df.groupby('start_station_name', observed=False).agg(trip_count=('ride_id', 'count')).nlargest(10, 'trip_count')
#     .reset_index()
# )

# # Merge with stations dataframe to get latitude and longitude
# top_stations_2023 = top_stations.merge(stations, left_on='start_station_name', right_on='station')

# %%
# Compute the map center based on mean latitude and longitude
map_center = [top_stations['lat'].mean(), top_stations['lng'].mean()]
top_stations_map = folium.Map(location=map_center, zoom_start=12)

# Add GeoJSON layers
folium.GeoJson("Neighborhood_Planning_Areas.geojson", name="Neighborhood").add_to(top_stations_map)
folium.GeoJson("Wards_from_2012.geojson", name="Wards").add_to(top_stations_map)
folium.GeoJson("Capital_Bikeshare_Locations.geojson", name="Capital_Bike_Share").add_to(top_stations_map)
folium.GeoJson("Metro_Bus_Lines.geojson", name="Bus_route").add_to(top_stations_map)


# Add markers for the top 10 stations
for _, row in top_stations_2023.iterrows():
    folium.Marker(
        location=[row['lat'], row['lng']],
        popup=folium.Popup(f"{row['start_station_name']} ({row['trip_count']} trips)", max_width=250),
        icon=folium.Icon(color='blue', icon='bicycle', prefix='fa')
    ).add_to(top_stations_map)

# Add layer control for toggling layers
folium.LayerControl().add_to(top_stations_map)

# Display map
top_stations_map
